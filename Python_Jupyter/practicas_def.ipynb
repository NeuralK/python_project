# %%
def saludar(nombres):

    for nombre in nombres:
        msg = f"Hola, {nombre}"
        print(msg)

nombres = ["María", "jose", "antonio", "pedrito"]

saludar(nombres)
# Out:
# Hola, María
# Hola, jose
# Hola, antonio
# Hola, pedrito

# %%
def saludar(nombres):

    for nombre in nombres:
        msg = f"Hola, {nombre}"
        print(msg)

nombres = ["María", "jose", "antonio", "pedrito"]

saludar(nombres)
# Out:
# Hola, María
# Hola, jose
# Hola, antonio
# Hola, pedrito

# %%
def saludar(nombres):

    for nombre in nombres:
        msg = f"Hola, {nombre}"
        print(msg)

nombres = ["María", "jose", "antonio", "pedrito"]

saludar(nombres)
# Out:
# Hola, María
# Hola, jose
# Hola, antonio
# Hola, pedrito
