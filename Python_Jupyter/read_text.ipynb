# %%
from pathlib import Path

path = Path("Python_lecciones.txt")
contents = path.read_text()






banana = contents.replace("python", "C++")

print(banana)

for line in contents.splitlines():
    print(line)
# Out:
# En lo que llevo estudiando C++, aprendi muchos conceptos nuevos, pero a la vez
# me di cuenta que yo no se absolutamente nada.
# Me falta mucho por aprender, no soy un fracasado,
# pero debo seguir siendo exigente para llegar a donde quiero llegar,
# la persona que mas amo soy yo mismo.
# En lo que llevo estudiando python, aprendi muchos conceptos nuevos, pero a la vez
# me di cuenta que yo no se absolutamente nada.
# Me falta mucho por aprender, no soy un fracasado,
# pero debo seguir siendo exigente para llegar a donde quiero llegar,
# la persona que mas amo soy yo mismo.

# %%
#Nos quedamos aca, leyendo el texto, empezamos el capitulo 10.

from pathlib import Path


path = Path("pi_digits.txt")
contents = path.read_text()
print(contents)
# Out:
# 3.1415926535
# 8979323846
# 2643383279
