# %%
from pathlib import Path
path = Path("../archivo_read/gatos.txt")
try:
    contents = path.read_text()
    print(contents)
except:

# %%
from pathlib import Path
path = Path("../Esto_es_nuevo/perros.txt")
try:
    contents = path.read_text()
    print(contents)
except:
    print(f"No se encontro: {path}")

# %%
from pathlib import Path
path = Path("Esto_es_nuevo/perros.txt")
try:
    contents = path.read_text()
    print(contents)
except:
    pass

# %%
while True:

   
    n1 = input("Introduce el primer número: ")

    n2 = input("Introduce el segundo número: ")
    if n1 == "q" or n2 == "q":
        break

    try:
        resultado = int(n1) + int(n2)
        print(resultado)
    
    except:
        print("No puedes usar letras bobolon......")
