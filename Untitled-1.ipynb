# %%
a = "zapato"
b = """Me la turbo pela perra"""
print(a, b)
# Out:
# zapato Me la turbo pela perra

# %%
banana = [1, 2, 3, 4, 5]

for mono in banana:
    print(mono)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
comando = ""
while True:
    comando = input("$")
    print(comando)
    if comando.lower() == "salir":
        break
# Out:
# hola
# salir

# %%
MANZANA=2
banana = "salame"
print(banana, MANZANA)
# Out:
# salame 2

# %%
comando = ""
while comando.lower() != "salir":
    comando = input("$")
    print(comando)
# Out:
# ca
# s}
# sad
# as
# d
# d
# sa
# d
# as
# d
# as
# d
# as
# das
# d
# as
# d
# as

# %%
numero = 1
while numero < 200:
    numero *= 2
    print(numero)
# Out:
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256

# %%
for banana in "potatoe":
    print(banana)
# Out:
# p
# o
# t
# a
# t
# o
# e

# %%
buscar = 5
for numero in range(5):
    print(numero)
    if numero == buscar:
        print("encontrado", buscar)
        break
else:
    print("jefecito, no encontre nada")
# Out:
# 0
# 1
# 2
# 3
# 4
# jefecito, no encontre nada

# %%
for numero in range(5):
    print(numero, numero * " hola pepe")
# Out:
# 0
# 1  hola pepe
# 2  hola pepe hola pepe
# 3  hola pepe hola pepe hola pepe
# 4  hola pepe hola pepe hola pepe hola pepe
