# %%
while True:
 n1 = input("ingresar el primer numero ")
 if n1.lower() == "salir":
  print("cerrando")
  
  break
 operacion = input("¿Que operación quieres realizar?: (suma, resta, div, mltp, elevar)")
 n2 = input("ingresar segundo numero ")
 if n1.isdigit() and n2.isdigit():
  n1 = int(n1)
  n2 = int(n2)
  


  if operacion == "suma":
   resultado = n1 + n2
   print(f"Segun mis calculos jefesito el resultado es: {resultado}")
  elif operacion == "resta":
   resultado = n1 - n2
   print(f"Segun mis calculos jefesito el resultado es: {resultado}")  
  elif operacion == "div":
   if n2 != 0:
       resultado = n1 / n2
       print(f"Segun mis calculos jefesito el resultado es: {resultado}")
   else:
       print("¿Que mierda haces? Es imposible dividir entre 0")
  elif operacion == "mltp":
   resultado = n1 * n2
   print(f"Segun mis calculos jefesito el resultado es: {resultado}")
  elif operacion == "elevar": 
   resultado = n1 ** n2
   print(f"Segun mis calculos jefesito el resultado es: {resultado}")
  
  else:
   print("¿acaso eres idiota? Elige entre las opciones que te di:")
  



  
 else:
   print("Que haces anormal, es una calculadora idiota:")
 
 
input("escribe en el numero 1: salir para poder finalizar el proceso:")
# Out:
# cerrando
# 'Salir'

# %%
while True:

 n1 = input("ingresar el primer numero")
 n2 = input("ingresar segundo numero")
 if n1.isdigit() and n2.isdigit():
  n1 = int(n1)
  n2 = int(n2)
  break
 else:
  print("Que haces anormal, es una calculadora idiota")

suma = n1 + n2
resta = n1 - n2
div = n1 / n2
mltp = n1 * n2
elevar = n1 ** n2

manzana = f"""
para los numeros {n1},{n2}
el resultado de la suma es {suma}
el resultado de la resta es {resta}
el resultado de la division es {div}
el resultado de la multiplicacion es {mltp}
el resultado de la elevacion es {elevar}
"""

print(manzana)
# Out:
# Que haces anormal, es una calculadora idiota
# Que haces anormal, es una calculadora idiota
#
# para los numeros 25,25
# el resultado de la suma es 50
# el resultado de la resta es 0
# el resultado de la division es 1.0
# el resultado de la multiplicacion es 625
# el resultado de la elevacion es 88817841970012523233890533447265625

# %%
pip install pyinstaller
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 10.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 16.9 MB/s  0:00:00
# ...
#
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
#    ------ --------------------------------- 1/6 [setuptools]
# ...
